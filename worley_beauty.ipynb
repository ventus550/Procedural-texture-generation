# %%
import numpy as np
from engine import Heatmap, Noise
from noises import smooth, heat, worley
from utilities import *

# %%
plates = 1 - worley(500, 100, 1)
landmass = heat(500, 20, 250, 250)
Heatmap(plates, landmass, 4*plates + landmass, scale = 2.0, cmap='flag')
# [red blue white red blue white ...]

# %%
plates = 1 - worley(500, 100, 3)
landmass = heat(500, 20, 250, 250)
Heatmap(landmass, 4*plates + landmass, plates, scale = 2.0, cmap='hot')

# %%
plates = 1 - worley(700, 100, 1)
Heatmap(plates, cmap='gray_r', scale = 3)
